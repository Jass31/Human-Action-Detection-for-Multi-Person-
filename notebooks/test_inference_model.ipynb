# %%
# %cd ..
# Out:
# /Users/jashtandel/SEM6/Approach2

# %% [markdown]
# ## Testing Inference on Video

# %%
import cv2
import numpy as np
import streamlit as st
import torch
import time
from src.detection_keypoint import DetectKeypoint
from src.classification_keypoint import AngleLSTMNet, AngleFeatureExtractor
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Initialize label encoder with the same classes used during training
def initialize_label_encoder():
    train_data = pd.read_csv('/Users/jashtandel/SEM6/Approach2/datasets/train_action_pose_keypoint.csv')
    label_encoder = LabelEncoder()
    label_encoder.fit(train_data['label'])
    return label_encoder

def extract_keypoints_and_angles(results, person_idx):
    """
    Extract keypoints from YOLOv8 pose detection results and convert to angular features
    for a single person.
    """
    try:
        keypoints = results.keypoints[person_idx]
        keypoints_xy = keypoints.xy[0].cpu().numpy()
        keypoints_flat = keypoints_xy.flatten()
        
        # Normalize coordinates
        img_height, img_width = results.orig_shape
        keypoints_flat[::2] /= img_width
        keypoints_flat[1::2] /= img_height
        
        angle_extractor = AngleFeatureExtractor()
        angles = angle_extractor.calculate_angles(keypoints_flat)
        angles_tensor = torch.tensor(angles, dtype=torch.float32).reshape(1, 1, 8)
        return angles_tensor
    except Exception as e:
        print(f"Error extracting keypoints and angles: {str(e)}")
        return None

def pose_classification_video(video_path, output_path):
    label_encoder = initialize_label_encoder()
    detection_keypoint = DetectKeypoint()
    
    model = AngleLSTMNet(
        input_size=8,
        hidden_size=128,
        num_layers=3,
        num_classes=len(label_encoder.classes_),
        lstm_dropout=0.3,
        fc_dropout=0.5
    )
    
    model.load_state_dict(torch.load('/Users/jashtandel/SEM6/YoloV8-Pose-Keypoint-Classification-master/models/HAAD_Pose_Angle.pt'))
    model.eval()
    
    cap = cv2.VideoCapture(video_path)
    st_frame = st.empty()
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    # FPS calculation variables
    prev_time = 0
    curr_time = 0
    fps_avg = []
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
            
        # Calculate FPS
        curr_time = time.time()
        fps = 1 / (curr_time - prev_time) if prev_time > 0 else 0
        prev_time = curr_time
        fps_avg.append(fps)
        if len(fps_avg) > 30:  # Average over last 30 frames
            fps_avg.pop(0)
        avg_fps = sum(fps_avg) / len(fps_avg)
            
        results = detection_keypoint(frame)
        classifications = []
        probabilities = []  # Store probabilities for each person
        num_persons = len(results.boxes)
        
        for i in range(num_persons):
            try:
                angles_tensor = extract_keypoints_and_angles(results, i)
                
                if angles_tensor is not None:
                    with torch.no_grad():
                        outputs = model(angles_tensor)
                        probabilities_tensor = torch.nn.functional.softmax(outputs.data, dim=1)
                        prob_values, predicted = torch.max(probabilities_tensor, 1)
                        action_label = label_encoder.inverse_transform([predicted.item()])[0]
                        classifications.append(action_label)
                        probabilities.append(prob_values.item())
                else:
                    classifications.append("unknown")
                    probabilities.append(0.0)
            except Exception as e:
                print(f"Error processing person {i}: {str(e)}")
                classifications.append("unknown")
                probabilities.append(0.0)
        
        frame_draw = results.plot(boxes=False)
        
        # Draw FPS
        cv2.putText(
            frame_draw,
            f'FPS: {avg_fps:.1f}',
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 255, 0), 2
        )
        
        # Draw bounding boxes and labels for each person
        for i, (action_label, probability) in enumerate(zip(classifications, probabilities)):
            if i < len(results.boxes):
                x_min, y_min, x_max, y_max = results.boxes.xyxy[i].cpu().numpy()
                
                # Draw bounding box
                frame_draw = cv2.rectangle(
                    frame_draw, 
                    (int(x_min), int(y_min)), (int(x_max), int(y_max)), 
                    (0, 0, 255), 2
                )
                
                # Create label with probability
                label_text = f'{action_label.upper()} ({probability:.2%})'
                
                # Draw label background
                (w, h), _ = cv2.getTextSize(
                    label_text, 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2
                )
                frame_draw = cv2.rectangle(
                    frame_draw, 
                    (int(x_min), int(y_min)-20), (int(x_min)+w, int(y_min)), 
                    (0, 0, 255), -1
                )
                
                # Draw label text with probability
                frame_draw = cv2.putText(
                    frame_draw,
                    label_text,
                    (int(x_min), int(y_min)-4),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5, (255, 255, 255),
                    thickness=2
                )
        
        # Update Streamlit display
        frame_draw_rgb = cv2.cvtColor(frame_draw, cv2.COLOR_BGR2RGB)
        st_frame.image(frame_draw_rgb, channels="RGB")
        
        out.write(frame_draw)
    
    cap.release()
    out.release()

# Streamlit app layout
st.set_page_config(layout="wide", page_title="YoloV8 Multi-Person Keypoint Classification Video")
st.write("## YoloV8 Multi-Person Keypoint Clasxsification in Video")
st.write("Upload a video to classify actions for multiple people in real-time.")

# Sidebar for video upload
st.sidebar.write("## Upload Video :gear:")
video_upload = st.sidebar.file_uploader("Upload a video", type=["mp4", "mov", "avi"])

if video_upload is not None:
    video_path = f"/tmp/{video_upload.name}"
    with open(video_path, "wb") as f:
        f.write(video_upload.getbuffer())
else:
    video_path = '/Users/jashtandel/Downloads/PETS09-S2L1-raw.mp4'

output_path = '/Users/jashtandel/SEM6/Approach2/output/annotated_output_multi_Impor.mp4'

# Run pose classification
pose_classification_video(video_path, output_path)
# Out:
# 2024-11-22 17:41:43.108
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# WARNING ⚠️ NMS time limit 2.050s exceeded
# 0: 480x640 2 persons, 480.9ms
# Speed: 77.2ms preprocess, 480.9ms inference, 5599.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 280.0ms
# Speed: 6.5ms preprocess, 280.0ms inference, 120.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.8ms
# Speed: 2.2ms preprocess, 130.8ms inference, 382.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.9ms
# Speed: 2.2ms preprocess, 128.9ms inference, 81.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.3ms
# Speed: 1.9ms preprocess, 120.3ms inference, 50.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.0ms
# Speed: 1.9ms preprocess, 120.0ms inference, 57.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.7ms
# Speed: 3.3ms preprocess, 122.7ms inference, 51.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Speed: 2.1ms preprocess, 118.5ms inference, 103.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.7ms
# Speed: 1.8ms preprocess, 119.7ms inference, 42.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.9ms preprocess, 122.8ms inference, 40.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.7ms
# Speed: 2.6ms preprocess, 114.7ms inference, 53.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.9ms
# Speed: 2.4ms preprocess, 124.9ms inference, 45.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.8ms
# Speed: 2.2ms preprocess, 122.8ms inference, 87.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.6ms
# Speed: 1.9ms preprocess, 131.6ms inference, 88.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Speed: 2.0ms preprocess, 119.4ms inference, 49.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.3ms
# Speed: 2.0ms preprocess, 119.3ms inference, 49.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.5ms
# Speed: 1.9ms preprocess, 121.5ms inference, 88.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 131.9ms
# Speed: 3.5ms preprocess, 131.9ms inference, 86.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 136.9ms
# Speed: 1.8ms preprocess, 136.9ms inference, 53.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.0ms
# Speed: 1.9ms preprocess, 122.0ms inference, 76.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.1ms
# Speed: 1.8ms preprocess, 126.1ms inference, 48.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.2ms
# Speed: 1.8ms preprocess, 125.2ms inference, 48.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.1ms
# Speed: 1.8ms preprocess, 125.1ms inference, 79.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.2ms
# Speed: 1.7ms preprocess, 125.2ms inference, 50.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.4ms
# Speed: 2.0ms preprocess, 127.4ms inference, 49.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.5ms
# Speed: 2.1ms preprocess, 123.5ms inference, 83.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 130.6ms
# Speed: 2.3ms preprocess, 130.6ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.3ms
# Speed: 2.1ms preprocess, 124.3ms inference, 47.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 136.3ms
# Speed: 2.0ms preprocess, 136.3ms inference, 45.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.1ms
# Speed: 1.9ms preprocess, 165.1ms inference, 34.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.0ms
# Speed: 1.9ms preprocess, 126.0ms inference, 49.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.2ms
# Speed: 1.9ms preprocess, 121.2ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 132.2ms
# Speed: 2.8ms preprocess, 132.2ms inference, 51.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.8ms
# Speed: 1.8ms preprocess, 120.8ms inference, 83.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.0ms
# Speed: 1.8ms preprocess, 127.0ms inference, 126.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 148.4ms
# Speed: 3.2ms preprocess, 148.4ms inference, 44.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.3ms
# Speed: 2.1ms preprocess, 129.3ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.8ms
# Speed: 1.9ms preprocess, 125.8ms inference, 83.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.6ms
# Speed: 1.8ms preprocess, 119.6ms inference, 52.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 118.5ms
# Speed: 1.9ms preprocess, 118.5ms inference, 122.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 124.2ms
# Speed: 1.9ms preprocess, 124.2ms inference, 79.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 134.1ms
# Speed: 2.0ms preprocess, 134.1ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.7ms
# Speed: 1.9ms preprocess, 133.7ms inference, 53.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.2ms
# Speed: 1.8ms preprocess, 117.2ms inference, 51.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 117.1ms
# Speed: 1.9ms preprocess, 117.1ms inference, 81.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.3ms
# Speed: 1.9ms preprocess, 129.3ms inference, 54.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 123.9ms
# Speed: 1.9ms preprocess, 123.9ms inference, 47.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.1ms
# Speed: 1.9ms preprocess, 130.1ms inference, 47.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.0ms
# Speed: 1.6ms preprocess, 120.0ms inference, 48.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 48.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 133.0ms
# Speed: 1.8ms preprocess, 133.0ms inference, 81.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.0ms
# Speed: 1.8ms preprocess, 130.0ms inference, 49.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.1ms
# Speed: 1.9ms preprocess, 119.1ms inference, 50.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.2ms
# Speed: 1.8ms preprocess, 118.2ms inference, 55.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.8ms
# Speed: 2.4ms preprocess, 120.8ms inference, 49.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.2ms
# Speed: 2.1ms preprocess, 119.2ms inference, 50.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.3ms
# Speed: 1.9ms preprocess, 122.3ms inference, 55.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.3ms
# Speed: 2.1ms preprocess, 119.3ms inference, 55.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 1.7ms preprocess, 117.1ms inference, 50.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 51.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.3ms
# Speed: 1.8ms preprocess, 121.3ms inference, 49.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.7ms
# Speed: 1.8ms preprocess, 124.7ms inference, 54.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Speed: 2.5ms preprocess, 119.5ms inference, 47.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.5ms
# Speed: 1.8ms preprocess, 117.5ms inference, 49.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 1.9ms preprocess, 117.1ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.6ms
# Speed: 1.9ms preprocess, 119.6ms inference, 51.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.4ms
# Speed: 2.0ms preprocess, 118.4ms inference, 50.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Speed: 1.9ms preprocess, 119.5ms inference, 47.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.1ms
# Speed: 2.2ms preprocess, 119.1ms inference, 48.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Speed: 1.9ms preprocess, 119.4ms inference, 47.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.8ms
# Speed: 1.8ms preprocess, 119.8ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.0ms
# Speed: 1.8ms preprocess, 117.0ms inference, 49.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.9ms
# Speed: 2.2ms preprocess, 118.9ms inference, 49.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 51.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.1ms
# Speed: 1.9ms preprocess, 118.1ms inference, 82.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.2ms
# Speed: 1.8ms preprocess, 119.2ms inference, 49.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.8ms
# Speed: 1.9ms preprocess, 116.8ms inference, 50.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.6ms
# Speed: 2.5ms preprocess, 114.6ms inference, 121.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Speed: 1.9ms preprocess, 118.5ms inference, 1236.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.2ms
# Speed: 2.3ms preprocess, 127.2ms inference, 49.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.7ms
# Speed: 2.0ms preprocess, 119.7ms inference, 41.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.7ms
# Speed: 2.1ms preprocess, 122.7ms inference, 40.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.1ms
# Speed: 2.5ms preprocess, 122.1ms inference, 39.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.0ms
# Speed: 2.6ms preprocess, 124.0ms inference, 39.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.7ms
# Speed: 2.6ms preprocess, 125.7ms inference, 84.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.3ms
# Speed: 1.9ms preprocess, 123.3ms inference, 42.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.2ms
# Speed: 3.3ms preprocess, 123.2ms inference, 40.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 2.1ms preprocess, 122.5ms inference, 39.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.7ms
# Speed: 2.5ms preprocess, 125.7ms inference, 38.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.2ms
# Speed: 2.4ms preprocess, 126.2ms inference, 37.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.1ms
# Speed: 2.6ms preprocess, 124.1ms inference, 38.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 115.3ms
# Speed: 2.9ms preprocess, 115.3ms inference, 47.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.9ms
# Speed: 1.9ms preprocess, 125.9ms inference, 37.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 134.5ms
# Speed: 2.6ms preprocess, 134.5ms inference, 33.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.9ms
# Speed: 1.9ms preprocess, 125.9ms inference, 39.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.8ms
# Speed: 2.9ms preprocess, 124.8ms inference, 38.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.0ms
# Speed: 2.1ms preprocess, 126.0ms inference, 38.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 130.6ms
# Speed: 1.9ms preprocess, 130.6ms inference, 35.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 135.9ms
# Speed: 2.4ms preprocess, 135.9ms inference, 28.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.6ms
# Speed: 2.7ms preprocess, 125.6ms inference, 37.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.3ms
# Speed: 2.7ms preprocess, 125.3ms inference, 38.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.2ms
# Speed: 2.8ms preprocess, 123.2ms inference, 38.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.0ms
# Speed: 2.4ms preprocess, 122.0ms inference, 38.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.7ms
# Speed: 2.3ms preprocess, 125.7ms inference, 37.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.4ms
# Speed: 2.8ms preprocess, 124.4ms inference, 37.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.7ms
# Speed: 4.4ms preprocess, 120.7ms inference, 41.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.9ms
# Speed: 2.3ms preprocess, 122.9ms inference, 39.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.1ms
# Speed: 2.8ms preprocess, 124.1ms inference, 38.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.7ms
# Speed: 2.1ms preprocess, 124.7ms inference, 38.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.1ms
# Speed: 2.6ms preprocess, 123.1ms inference, 37.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.4ms
# Speed: 2.1ms preprocess, 122.4ms inference, 38.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.4ms preprocess, 122.8ms inference, 38.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.3ms preprocess, 122.8ms inference, 38.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.3ms preprocess, 122.8ms inference, 38.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.4ms
# Speed: 2.6ms preprocess, 122.4ms inference, 37.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.1ms
# Speed: 2.7ms preprocess, 123.1ms inference, 37.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.1ms
# Speed: 2.8ms preprocess, 122.1ms inference, 37.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.0ms
# Speed: 2.9ms preprocess, 121.0ms inference, 40.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.1ms
# Speed: 2.4ms preprocess, 125.1ms inference, 84.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.1ms
# Speed: 1.8ms preprocess, 125.1ms inference, 52.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.9ms
# Speed: 3.0ms preprocess, 118.9ms inference, 41.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.0ms
# Speed: 2.1ms preprocess, 125.0ms inference, 39.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.8ms
# Speed: 3.5ms preprocess, 121.8ms inference, 39.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.1ms
# Speed: 2.4ms preprocess, 121.1ms inference, 39.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.6ms
# Speed: 2.7ms preprocess, 122.6ms inference, 37.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.4ms
# Speed: 2.0ms preprocess, 119.4ms inference, 41.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.4ms
# Speed: 2.3ms preprocess, 120.4ms inference, 39.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.2ms
# Speed: 2.3ms preprocess, 122.2ms inference, 38.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.7ms preprocess, 122.8ms inference, 38.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.6ms
# Speed: 2.6ms preprocess, 121.6ms inference, 37.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Speed: 2.2ms preprocess, 123.1ms inference, 49.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.9ms
# Speed: 3.5ms preprocess, 116.9ms inference, 42.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.4ms
# Speed: 2.1ms preprocess, 124.4ms inference, 47.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.7ms
# Speed: 2.3ms preprocess, 119.7ms inference, 47.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Speed: 1.9ms preprocess, 120.2ms inference, 49.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Speed: 1.9ms preprocess, 122.8ms inference, 55.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.2ms
# Speed: 1.9ms preprocess, 117.2ms inference, 51.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.9ms
# Speed: 1.9ms preprocess, 122.9ms inference, 43.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.9ms
# Speed: 2.5ms preprocess, 119.9ms inference, 57.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Speed: 1.8ms preprocess, 118.8ms inference, 50.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.2ms
# Speed: 1.7ms preprocess, 121.2ms inference, 40.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.3ms
# Speed: 2.2ms preprocess, 123.3ms inference, 38.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.8ms
# Speed: 2.5ms preprocess, 135.8ms inference, 52.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.2ms
# Speed: 2.7ms preprocess, 126.2ms inference, 46.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.1ms
# Speed: 3.4ms preprocess, 143.1ms inference, 44.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.2ms
# Speed: 1.8ms preprocess, 115.2ms inference, 59.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 130.3ms
# Speed: 2.5ms preprocess, 130.3ms inference, 45.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.8ms
# Speed: 4.2ms preprocess, 138.8ms inference, 52.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.8ms
# Speed: 1.9ms preprocess, 121.8ms inference, 68.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.4ms
# Speed: 1.7ms preprocess, 120.4ms inference, 45.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.4ms
# Speed: 1.7ms preprocess, 143.4ms inference, 45.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 136.1ms
# Speed: 2.0ms preprocess, 136.1ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.8ms
# Speed: 2.3ms preprocess, 124.8ms inference, 43.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 129.7ms
# Speed: 2.0ms preprocess, 129.7ms inference, 52.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 127.5ms
# Speed: 2.9ms preprocess, 127.5ms inference, 49.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.9ms
# Speed: 1.6ms preprocess, 121.9ms inference, 46.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 130.7ms
# Speed: 2.1ms preprocess, 130.7ms inference, 45.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 157.9ms
# Speed: 2.0ms preprocess, 157.9ms inference, 113.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.3ms
# Speed: 2.2ms preprocess, 200.3ms inference, 140.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.0ms
# Speed: 2.8ms preprocess, 129.0ms inference, 47.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.9ms
# Speed: 2.7ms preprocess, 120.9ms inference, 42.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.2ms
# Speed: 22.0ms preprocess, 126.2ms inference, 41.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.2ms
# Speed: 2.8ms preprocess, 120.2ms inference, 38.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.9ms
# Speed: 7.0ms preprocess, 112.9ms inference, 71.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.9ms
# Speed: 3.4ms preprocess, 141.9ms inference, 40.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.7ms
# Speed: 2.3ms preprocess, 122.7ms inference, 42.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.3ms
# Speed: 2.0ms preprocess, 124.3ms inference, 38.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.9ms
# Speed: 3.2ms preprocess, 121.9ms inference, 39.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.1ms
# Speed: 2.4ms preprocess, 123.1ms inference, 44.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Speed: 1.9ms preprocess, 120.9ms inference, 51.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.5ms
# Speed: 2.0ms preprocess, 115.5ms inference, 50.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.3ms
# Speed: 2.0ms preprocess, 122.3ms inference, 42.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.3ms
# Speed: 2.5ms preprocess, 124.3ms inference, 38.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.8ms
# Speed: 2.5ms preprocess, 123.8ms inference, 37.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.4ms
# Speed: 5.1ms preprocess, 126.4ms inference, 49.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.2ms
# Speed: 1.9ms preprocess, 120.2ms inference, 42.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 131.9ms
# Speed: 2.2ms preprocess, 131.9ms inference, 41.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.5ms
# Speed: 2.1ms preprocess, 122.5ms inference, 52.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.2ms
# Speed: 2.8ms preprocess, 124.2ms inference, 45.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.2ms
# Speed: 2.2ms preprocess, 123.2ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 56.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 130.1ms
# Speed: 1.9ms preprocess, 130.1ms inference, 53.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.5ms
# Speed: 1.9ms preprocess, 127.5ms inference, 51.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.5ms
# Speed: 1.9ms preprocess, 128.5ms inference, 54.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.3ms
# Speed: 1.7ms preprocess, 126.3ms inference, 55.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.1ms
# Speed: 1.9ms preprocess, 118.1ms inference, 50.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.8ms
# Speed: 2.1ms preprocess, 128.8ms inference, 46.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.4ms
# Speed: 1.9ms preprocess, 127.4ms inference, 46.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.4ms
# Speed: 1.9ms preprocess, 124.4ms inference, 47.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.0ms
# Speed: 1.9ms preprocess, 123.0ms inference, 47.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.0ms
# Speed: 2.1ms preprocess, 120.0ms inference, 55.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.4ms
# Speed: 1.9ms preprocess, 126.4ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.2ms
# Speed: 3.0ms preprocess, 129.2ms inference, 55.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 48.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.8ms
# Speed: 1.9ms preprocess, 123.8ms inference, 51.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.6ms
# Speed: 2.1ms preprocess, 125.6ms inference, 46.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.3ms
# Speed: 1.9ms preprocess, 120.3ms inference, 47.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.0ms
# Speed: 2.4ms preprocess, 124.0ms inference, 47.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.1ms
# Speed: 2.5ms preprocess, 129.1ms inference, 46.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.8ms
# Speed: 1.9ms preprocess, 125.8ms inference, 47.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.3ms
# Speed: 1.9ms preprocess, 126.3ms inference, 49.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 137.5ms
# Speed: 2.7ms preprocess, 137.5ms inference, 48.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 132.7ms
# Speed: 1.9ms preprocess, 132.7ms inference, 49.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.4ms
# Speed: 1.8ms preprocess, 123.4ms inference, 47.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.7ms
# Speed: 2.2ms preprocess, 129.7ms inference, 46.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.9ms
# Speed: 1.8ms preprocess, 125.9ms inference, 47.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 137.6ms
# Speed: 2.1ms preprocess, 137.6ms inference, 45.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.0ms
# Speed: 1.9ms preprocess, 117.0ms inference, 54.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 134.0ms
# Speed: 1.9ms preprocess, 134.0ms inference, 47.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 132.3ms
# Speed: 2.4ms preprocess, 132.3ms inference, 49.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.2ms
# Speed: 2.0ms preprocess, 121.2ms inference, 47.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.9ms
# Speed: 1.9ms preprocess, 118.9ms inference, 56.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Speed: 2.3ms preprocess, 120.9ms inference, 48.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Speed: 1.9ms preprocess, 120.2ms inference, 47.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.2ms
# Speed: 1.9ms preprocess, 119.2ms inference, 46.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Speed: 2.0ms preprocess, 120.3ms inference, 56.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Speed: 1.9ms preprocess, 120.9ms inference, 54.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Speed: 2.4ms preprocess, 118.8ms inference, 47.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.4ms
# Speed: 2.0ms preprocess, 118.4ms inference, 49.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.4ms
# Speed: 2.0ms preprocess, 117.4ms inference, 49.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.4ms
# Speed: 1.9ms preprocess, 117.4ms inference, 49.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.4ms
# Speed: 2.1ms preprocess, 121.4ms inference, 46.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.6ms
# Speed: 1.9ms preprocess, 121.6ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.7ms
# Speed: 1.9ms preprocess, 122.7ms inference, 49.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Speed: 2.4ms preprocess, 119.5ms inference, 48.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.8ms
# Speed: 2.0ms preprocess, 118.8ms inference, 48.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.6ms
# Speed: 1.8ms preprocess, 118.6ms inference, 48.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 130.6ms
# Speed: 1.9ms preprocess, 130.6ms inference, 47.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 123.8ms
# Speed: 2.1ms preprocess, 123.8ms inference, 56.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.8ms
# Speed: 2.1ms preprocess, 129.8ms inference, 47.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.2ms
# Speed: 1.9ms preprocess, 128.2ms inference, 48.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 131.6ms
# Speed: 2.1ms preprocess, 131.6ms inference, 47.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 133.0ms
# Speed: 2.1ms preprocess, 133.0ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.1ms
# Speed: 1.9ms preprocess, 124.1ms inference, 49.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.4ms
# Speed: 1.9ms preprocess, 122.4ms inference, 49.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.4ms
# Speed: 2.1ms preprocess, 122.4ms inference, 49.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.6ms
# Speed: 1.8ms preprocess, 120.6ms inference, 49.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.5ms
# Speed: 1.9ms preprocess, 121.5ms inference, 49.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.8ms
# Speed: 1.9ms preprocess, 120.8ms inference, 50.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.2ms
# Speed: 1.8ms preprocess, 122.2ms inference, 49.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.7ms
# Speed: 1.8ms preprocess, 121.7ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.7ms
# Speed: 1.8ms preprocess, 121.7ms inference, 48.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.4ms
# Speed: 2.4ms preprocess, 123.4ms inference, 47.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.1ms
# Speed: 1.8ms preprocess, 127.1ms inference, 49.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.6ms
# Speed: 1.9ms preprocess, 122.6ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.0ms
# Speed: 1.9ms preprocess, 126.0ms inference, 49.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.1ms
# Speed: 1.9ms preprocess, 123.1ms inference, 48.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.2ms
# Speed: 1.8ms preprocess, 120.2ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.1ms
# Speed: 1.8ms preprocess, 122.1ms inference, 48.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.6ms
# Speed: 1.8ms preprocess, 128.6ms inference, 49.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.6ms
# Speed: 1.8ms preprocess, 122.6ms inference, 48.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.2ms
# Speed: 1.8ms preprocess, 123.2ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.8ms
# Speed: 1.8ms preprocess, 122.8ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.6ms
# Speed: 2.0ms preprocess, 127.6ms inference, 48.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.7ms
# Speed: 2.6ms preprocess, 126.7ms inference, 50.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.9ms
# Speed: 1.9ms preprocess, 121.9ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.5ms
# Speed: 2.0ms preprocess, 126.5ms inference, 48.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.5ms
# Speed: 1.9ms preprocess, 121.5ms inference, 49.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.3ms
# Speed: 2.0ms preprocess, 123.3ms inference, 48.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.6ms
# Speed: 1.9ms preprocess, 120.6ms inference, 49.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.2ms
# Speed: 1.8ms preprocess, 129.2ms inference, 56.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.2ms
# Speed: 1.9ms preprocess, 129.2ms inference, 47.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.1ms
# Speed: 1.6ms preprocess, 125.1ms inference, 52.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.9ms
# Speed: 2.0ms preprocess, 117.9ms inference, 48.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 128.1ms
# Speed: 1.9ms preprocess, 128.1ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.1ms
# Speed: 1.8ms preprocess, 121.1ms inference, 51.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Speed: 1.9ms preprocess, 123.1ms inference, 48.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.7ms
# Speed: 1.9ms preprocess, 118.7ms inference, 51.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.4ms
# Speed: 2.0ms preprocess, 121.4ms inference, 55.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.5ms
# Speed: 2.1ms preprocess, 120.5ms inference, 50.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.9ms
# Speed: 1.9ms preprocess, 118.9ms inference, 46.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Speed: 2.0ms preprocess, 119.4ms inference, 48.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Speed: 2.9ms preprocess, 120.9ms inference, 46.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Speed: 1.9ms preprocess, 118.8ms inference, 47.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Speed: 1.9ms preprocess, 122.8ms inference, 55.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 2.0ms preprocess, 117.8ms inference, 41.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.3ms
# Speed: 2.2ms preprocess, 124.3ms inference, 39.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.1ms
# Speed: 2.5ms preprocess, 124.1ms inference, 39.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.2ms
# Speed: 2.1ms preprocess, 124.2ms inference, 43.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.6ms preprocess, 122.8ms inference, 42.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.2ms
# Speed: 2.3ms preprocess, 125.2ms inference, 56.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Speed: 2.3ms preprocess, 118.8ms inference, 55.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.7ms
# Speed: 2.0ms preprocess, 118.7ms inference, 41.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.5ms
# Speed: 3.0ms preprocess, 122.5ms inference, 54.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.5ms
# Speed: 1.7ms preprocess, 117.5ms inference, 48.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.2ms
# Speed: 1.8ms preprocess, 119.2ms inference, 40.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.2ms
# Speed: 3.0ms preprocess, 123.2ms inference, 45.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.3ms
# Speed: 2.0ms preprocess, 120.3ms inference, 41.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.7ms
# Speed: 2.6ms preprocess, 118.7ms inference, 54.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.0ms
# Speed: 2.8ms preprocess, 119.0ms inference, 42.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.0ms
# Speed: 2.3ms preprocess, 122.0ms inference, 39.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.7ms
# Speed: 2.0ms preprocess, 114.7ms inference, 45.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.9ms
# Speed: 1.9ms preprocess, 120.9ms inference, 42.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.3ms
# Speed: 18.0ms preprocess, 124.3ms inference, 60.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Speed: 2.1ms preprocess, 123.4ms inference, 45.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 39.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.0ms
# Speed: 2.5ms preprocess, 122.0ms inference, 39.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.9ms
# Speed: 2.8ms preprocess, 125.9ms inference, 40.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.4ms
# Speed: 2.5ms preprocess, 121.4ms inference, 42.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 130.5ms
# Speed: 1.8ms preprocess, 130.5ms inference, 31.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.7ms
# Speed: 2.9ms preprocess, 123.7ms inference, 36.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 2.6ms preprocess, 122.5ms inference, 38.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.3ms
# Speed: 2.8ms preprocess, 124.3ms inference, 37.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.9ms
# Speed: 2.7ms preprocess, 120.9ms inference, 38.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.5ms
# Speed: 2.9ms preprocess, 126.5ms inference, 37.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.0ms
# Speed: 2.5ms preprocess, 123.0ms inference, 38.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.9ms
# Speed: 2.5ms preprocess, 120.9ms inference, 42.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.6ms
# Speed: 2.3ms preprocess, 126.6ms inference, 38.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.6ms
# Speed: 2.6ms preprocess, 126.6ms inference, 42.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.7ms
# Speed: 2.1ms preprocess, 121.7ms inference, 40.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.9ms
# Speed: 2.4ms preprocess, 119.9ms inference, 40.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 2.7ms preprocess, 122.5ms inference, 37.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.5ms
# Speed: 2.2ms preprocess, 125.5ms inference, 41.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 127.3ms
# Speed: 2.6ms preprocess, 127.3ms inference, 38.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.3ms
# Speed: 2.3ms preprocess, 123.3ms inference, 37.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.9ms
# Speed: 2.4ms preprocess, 123.9ms inference, 36.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.6ms
# Speed: 2.1ms preprocess, 122.6ms inference, 39.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.0ms
# Speed: 3.4ms preprocess, 119.0ms inference, 40.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.7ms
# Speed: 2.0ms preprocess, 122.7ms inference, 40.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.4ms
# Speed: 2.5ms preprocess, 125.4ms inference, 40.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.6ms
# Speed: 2.5ms preprocess, 123.6ms inference, 37.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.2ms
# Speed: 2.4ms preprocess, 121.2ms inference, 39.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.6ms
# Speed: 2.4ms preprocess, 126.6ms inference, 43.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.0ms
# Speed: 2.4ms preprocess, 122.0ms inference, 39.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.9ms
# Speed: 2.7ms preprocess, 122.9ms inference, 36.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.8ms
# Speed: 2.9ms preprocess, 123.8ms inference, 39.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.4ms
# Speed: 3.2ms preprocess, 121.4ms inference, 39.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.3ms
# Speed: 3.2ms preprocess, 120.3ms inference, 39.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.4ms
# Speed: 2.1ms preprocess, 123.4ms inference, 42.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.1ms
# Speed: 2.3ms preprocess, 124.1ms inference, 37.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.0ms
# Speed: 3.2ms preprocess, 123.0ms inference, 38.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.5ms
# Speed: 2.7ms preprocess, 124.5ms inference, 37.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.4ms
# Speed: 2.5ms preprocess, 124.4ms inference, 37.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.9ms
# Speed: 2.8ms preprocess, 122.9ms inference, 38.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.2ms
# Speed: 2.6ms preprocess, 123.2ms inference, 39.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.5ms
# Speed: 2.2ms preprocess, 121.5ms inference, 40.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.0ms
# Speed: 2.4ms preprocess, 121.0ms inference, 44.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.6ms
# Speed: 2.2ms preprocess, 122.6ms inference, 38.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.7ms
# Speed: 2.7ms preprocess, 122.7ms inference, 38.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.9ms
# Speed: 2.5ms preprocess, 120.9ms inference, 38.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.4ms preprocess, 122.8ms inference, 36.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.9ms
# Speed: 2.4ms preprocess, 121.9ms inference, 38.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.5ms
# Speed: 2.5ms preprocess, 121.5ms inference, 52.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.2ms
# Speed: 2.0ms preprocess, 118.2ms inference, 48.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.9ms
# Speed: 1.9ms preprocess, 117.9ms inference, 51.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.9ms
# Speed: 2.2ms preprocess, 115.9ms inference, 50.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.3ms
# Speed: 2.0ms preprocess, 118.3ms inference, 46.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Speed: 2.1ms preprocess, 123.1ms inference, 46.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.5ms
# Speed: 2.0ms preprocess, 117.5ms inference, 48.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.0ms
# Speed: 1.9ms preprocess, 117.0ms inference, 48.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.6ms
# Speed: 1.9ms preprocess, 121.6ms inference, 42.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.9ms
# Speed: 3.6ms preprocess, 119.9ms inference, 39.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.7ms
# Speed: 2.4ms preprocess, 121.7ms inference, 37.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.7ms
# Speed: 3.7ms preprocess, 121.7ms inference, 38.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.7ms
# Speed: 2.9ms preprocess, 123.7ms inference, 36.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.6ms
# Speed: 3.0ms preprocess, 121.6ms inference, 38.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.1ms
# Speed: 3.0ms preprocess, 124.1ms inference, 43.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.3ms
# Speed: 1.9ms preprocess, 125.3ms inference, 47.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 118.6ms
# Speed: 2.2ms preprocess, 118.6ms inference, 53.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.8ms
# ...
#
# 0: 480x640 2 persons, 119.2ms
# Speed: 2.3ms preprocess, 119.2ms inference, 49.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.4ms
# Speed: 2.0ms preprocess, 124.4ms inference, 47.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.7ms
# Speed: 1.9ms preprocess, 121.7ms inference, 46.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.9ms
# Speed: 2.0ms preprocess, 120.9ms inference, 50.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.7ms
# Speed: 2.1ms preprocess, 118.7ms inference, 51.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 134.9ms
# Speed: 2.0ms preprocess, 134.9ms inference, 46.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.2ms
# Speed: 1.9ms preprocess, 121.2ms inference, 47.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.5ms
# Speed: 2.0ms preprocess, 121.5ms inference, 46.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 46.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Speed: 2.0ms preprocess, 123.4ms inference, 45.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.4ms
# Speed: 1.8ms preprocess, 120.4ms inference, 51.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.9ms
# Speed: 1.9ms preprocess, 128.9ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.1ms
# Speed: 2.0ms preprocess, 120.1ms inference, 46.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.7ms
# Speed: 2.0ms preprocess, 120.7ms inference, 47.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.2ms
# Speed: 2.1ms preprocess, 119.2ms inference, 48.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.8ms
# Speed: 2.0ms preprocess, 118.8ms inference, 48.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.7ms
# Speed: 2.5ms preprocess, 119.7ms inference, 49.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 120.2ms
# Speed: 2.0ms preprocess, 120.2ms inference, 57.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.4ms
# Speed: 1.9ms preprocess, 121.4ms inference, 50.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.2ms
# Speed: 2.5ms preprocess, 118.2ms inference, 49.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Speed: 2.2ms preprocess, 118.5ms inference, 47.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.9ms
# Speed: 2.2ms preprocess, 119.9ms inference, 46.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Speed: 2.1ms preprocess, 120.2ms inference, 48.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.7ms
# Speed: 2.1ms preprocess, 127.7ms inference, 46.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.2ms
# Speed: 1.9ms preprocess, 117.2ms inference, 51.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 131.0ms
# Speed: 2.1ms preprocess, 131.0ms inference, 53.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.7ms
# Speed: 1.9ms preprocess, 122.7ms inference, 55.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.7ms
# Speed: 2.0ms preprocess, 118.7ms inference, 48.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Speed: 2.0ms preprocess, 118.8ms inference, 47.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.6ms
# Speed: 1.9ms preprocess, 118.6ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.0ms
# Speed: 2.5ms preprocess, 119.0ms inference, 48.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Speed: 1.9ms preprocess, 118.8ms inference, 47.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Speed: 2.4ms preprocess, 121.0ms inference, 48.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.7ms
# Speed: 2.0ms preprocess, 117.7ms inference, 49.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.9ms
# Speed: 1.9ms preprocess, 117.9ms inference, 47.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.9ms
# Speed: 2.2ms preprocess, 117.9ms inference, 57.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.1ms
# Speed: 2.1ms preprocess, 120.1ms inference, 54.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 47.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.4ms
# Speed: 1.8ms preprocess, 118.4ms inference, 48.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.4ms
# Speed: 2.1ms preprocess, 127.4ms inference, 49.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.3ms
# Speed: 1.9ms preprocess, 118.3ms inference, 47.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.6ms
# Speed: 2.0ms preprocess, 118.6ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.9ms
# Speed: 2.0ms preprocess, 118.9ms inference, 55.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.7ms
# Speed: 2.1ms preprocess, 121.7ms inference, 40.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 2.7ms preprocess, 122.5ms inference, 38.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.4ms
# Speed: 2.2ms preprocess, 123.4ms inference, 38.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.6ms
# Speed: 22.6ms preprocess, 122.6ms inference, 47.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.2ms
# Speed: 1.9ms preprocess, 116.2ms inference, 50.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.0ms
# Speed: 1.9ms preprocess, 119.0ms inference, 40.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.1ms
# Speed: 2.4ms preprocess, 125.1ms inference, 37.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.4ms
# Speed: 3.0ms preprocess, 122.4ms inference, 38.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 3.0ms preprocess, 122.5ms inference, 39.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.7ms
# Speed: 3.0ms preprocess, 122.7ms inference, 38.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.1ms
# Speed: 2.9ms preprocess, 126.1ms inference, 41.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.5ms
# Speed: 3.3ms preprocess, 124.5ms inference, 37.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.5ms
# Speed: 2.8ms preprocess, 123.5ms inference, 56.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.2ms
# Speed: 1.9ms preprocess, 121.2ms inference, 39.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.2ms
# Speed: 2.3ms preprocess, 123.2ms inference, 38.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.8ms
# Speed: 2.6ms preprocess, 123.8ms inference, 37.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.4ms
# Speed: 2.6ms preprocess, 122.4ms inference, 47.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.4ms
# Speed: 2.1ms preprocess, 118.4ms inference, 47.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.8ms
# Speed: 1.9ms preprocess, 119.8ms inference, 47.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Speed: 1.9ms preprocess, 120.3ms inference, 50.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.6ms
# Speed: 2.0ms preprocess, 120.6ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.7ms
# Speed: 2.0ms preprocess, 121.7ms inference, 45.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 2.0ms preprocess, 117.1ms inference, 48.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.5ms
# Speed: 1.9ms preprocess, 124.5ms inference, 48.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.1ms
# Speed: 2.0ms preprocess, 118.1ms inference, 48.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.0ms
# Speed: 1.8ms preprocess, 119.0ms inference, 41.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.4ms
# Speed: 2.4ms preprocess, 124.4ms inference, 49.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.7ms
# Speed: 2.1ms preprocess, 122.7ms inference, 47.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.9ms
# Speed: 2.0ms preprocess, 121.9ms inference, 46.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.0ms
# Speed: 2.1ms preprocess, 120.0ms inference, 54.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.1ms
# Speed: 2.0ms preprocess, 122.1ms inference, 40.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.3ms
# Speed: 2.4ms preprocess, 125.3ms inference, 45.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Speed: 2.5ms preprocess, 122.8ms inference, 45.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.6ms
# Speed: 1.8ms preprocess, 118.6ms inference, 55.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.4ms
# Speed: 1.9ms preprocess, 122.4ms inference, 53.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.8ms
# Speed: 1.9ms preprocess, 123.8ms inference, 52.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.4ms
# Speed: 2.2ms preprocess, 133.4ms inference, 51.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.3ms
# Speed: 2.0ms preprocess, 121.3ms inference, 46.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.9ms
# Speed: 1.9ms preprocess, 119.9ms inference, 50.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.2ms
# Speed: 2.0ms preprocess, 119.2ms inference, 47.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.9ms
# Speed: 2.0ms preprocess, 121.9ms inference, 55.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.8ms
# Speed: 2.2ms preprocess, 126.8ms inference, 47.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.9ms
# Speed: 1.9ms preprocess, 120.9ms inference, 53.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.0ms
# Speed: 1.8ms preprocess, 129.0ms inference, 49.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.6ms
# Speed: 2.1ms preprocess, 122.6ms inference, 48.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.6ms
# Speed: 2.2ms preprocess, 117.6ms inference, 49.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.1ms
# Speed: 2.1ms preprocess, 119.1ms inference, 50.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Speed: 2.0ms preprocess, 120.3ms inference, 48.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.0ms
# Speed: 1.8ms preprocess, 118.0ms inference, 48.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Speed: 2.1ms preprocess, 124.8ms inference, 57.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.3ms
# Speed: 1.9ms preprocess, 118.3ms inference, 48.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.4ms
# Speed: 2.3ms preprocess, 118.4ms inference, 55.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Speed: 1.9ms preprocess, 121.0ms inference, 54.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.2ms
# Speed: 1.9ms preprocess, 119.2ms inference, 56.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.7ms
# Speed: 2.0ms preprocess, 118.7ms inference, 41.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.4ms
# Speed: 2.4ms preprocess, 122.4ms inference, 53.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 131.8ms
# Speed: 1.9ms preprocess, 131.8ms inference, 45.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 51.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.3ms
# Speed: 2.0ms preprocess, 119.3ms inference, 52.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 121.0ms
# Speed: 2.0ms preprocess, 121.0ms inference, 53.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 130.4ms
# Speed: 1.9ms preprocess, 130.4ms inference, 54.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.6ms
# Speed: 1.8ms preprocess, 126.6ms inference, 51.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 130.1ms
# Speed: 2.0ms preprocess, 130.1ms inference, 56.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 129.1ms
# Speed: 2.2ms preprocess, 129.1ms inference, 57.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 128.3ms
# Speed: 1.9ms preprocess, 128.3ms inference, 52.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 128.7ms
# Speed: 1.8ms preprocess, 128.7ms inference, 46.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 130.1ms
# Speed: 1.9ms preprocess, 130.1ms inference, 44.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 130.0ms
# Speed: 1.9ms preprocess, 130.0ms inference, 55.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 126.1ms
# Speed: 1.8ms preprocess, 126.1ms inference, 48.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 132.1ms
# Speed: 2.0ms preprocess, 132.1ms inference, 47.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 132.0ms
# Speed: 6.1ms preprocess, 132.0ms inference, 56.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 133.6ms
# Speed: 2.1ms preprocess, 133.6ms inference, 53.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 131.9ms
# Speed: 1.8ms preprocess, 131.9ms inference, 57.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 138.0ms
# Speed: 1.9ms preprocess, 138.0ms inference, 53.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 131.7ms
# Speed: 2.5ms preprocess, 131.7ms inference, 53.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 130.4ms
# Speed: 1.9ms preprocess, 130.4ms inference, 49.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 132.2ms
# Speed: 1.8ms preprocess, 132.2ms inference, 45.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 129.9ms
# Speed: 1.9ms preprocess, 129.9ms inference, 46.6ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ## Testing Inference using Webcam

# %%
import cv2
import numpy as np
import torch
import time
from src.detection_keypoint import DetectKeypoint
from src.classification_keypoint import AngleLSTMNet, AngleFeatureExtractor
from sklearn.preprocessing import LabelEncoder
import pandas as pd

def initialize_label_encoder():
    """
    Initialize label encoder with classes from training data.
    
    Returns:
        LabelEncoder: Fitted label encoder
    """
    train_data = pd.read_csv('/Users/jashtandel/SEM6/Approach2/datasets/train_action_pose_keypoint.csv')
    label_encoder = LabelEncoder()
    label_encoder.fit(train_data['label'])
    return label_encoder

def extract_keypoints_and_angles(results, person_idx):
    """
    Extract keypoints from YOLOv8 pose detection results and convert to angular features
    for a single person.
    
    Args:
        results: Detection results
        person_idx: Index of the person to extract keypoints for
    
    Returns:
        torch.Tensor: Normalized angular features, or None if extraction fails
    """
    try:
        keypoints = results.keypoints[person_idx]
        keypoints_xy = keypoints.xy[0].cpu().numpy()
        keypoints_flat = keypoints_xy.flatten()
        
        # Normalize coordinates
        img_height, img_width = results.orig_shape
        keypoints_flat[::2] /= img_width
        keypoints_flat[1::2] /= img_height
        
        angle_extractor = AngleFeatureExtractor()
        angles = angle_extractor.calculate_angles(keypoints_flat)
        angles_tensor = torch.tensor(angles, dtype=torch.float32).reshape(1, 1, 8)
        return angles_tensor
    except Exception as e:
        print(f"Error extracting keypoints and angles: {str(e)}")
        return None

def pose_classification_webcam():
    """
    Perform real-time pose classification using webcam input.
    """
    # Initialize components
    label_encoder = initialize_label_encoder()
    detection_keypoint = DetectKeypoint()
    
    # Load pre-trained model
    model = AngleLSTMNet(
        input_size=8,
        hidden_size=128,
        num_layers=3,
        num_classes=len(label_encoder.classes_),
        lstm_dropout=0.3,
        fc_dropout=0.5
    )
    
    model.load_state_dict(torch.load('/Users/jashtandel/SEM6/YoloV8-Pose-Keypoint-Classification-master/models/HAAD_Pose_Angle.pt'))
    model.eval()
    
    # Open webcam
    cap = cv2.VideoCapture(0)  # 0 for default webcam
    
    # FPS calculation variables
    prev_time = 0
    fps_avg = []
    
    while True:
        # Read frame from webcam
        ret, frame = cap.read()
        if not ret:
            break
        
        # Calculate FPS
        curr_time = time.time()
        fps = 1 / (curr_time - prev_time) if prev_time > 0 else 0
        prev_time = curr_time
        fps_avg.append(fps)
        
        # Keep only last 30 FPS measurements
        if len(fps_avg) > 30:
            fps_avg.pop(0)
        avg_fps = sum(fps_avg) / len(fps_avg)
        
        # Perform pose detection
        results = detection_keypoint(frame)
        classifications = []
        probabilities = []
        num_persons = len(results.boxes)
        
        # Process each detected person
        for i in range(num_persons):
            try:
                angles_tensor = extract_keypoints_and_angles(results, i)
                
                if angles_tensor is not None:
                    with torch.no_grad():
                        outputs = model(angles_tensor)
                        probabilities_tensor = torch.nn.functional.softmax(outputs.data, dim=1)
                        prob_values, predicted = torch.max(probabilities_tensor, 1)
                        action_label = label_encoder.inverse_transform([predicted.item()])[0]
                        classifications.append(action_label)
                        probabilities.append(prob_values.item())
                else:
                    classifications.append("unknown")
                    probabilities.append(0.0)
            except Exception as e:
                print(f"Error processing person {i}: {str(e)}")
                classifications.append("unknown")
                probabilities.append(0.0)
        
        # Draw detection results
        frame_draw = results.plot(boxes=False)
        
        # Draw FPS
        cv2.putText(
            frame_draw,
            f'FPS: {avg_fps:.1f}',
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 255, 0), 2
        )
        
        # Draw bounding boxes and labels for each person
        for i, (action_label, probability) in enumerate(zip(classifications, probabilities)):
            if i < len(results.boxes):
                x_min, y_min, x_max, y_max = results.boxes.xyxy[i].cpu().numpy()
                
                # Draw bounding box
                frame_draw = cv2.rectangle(
                    frame_draw, 
                    (int(x_min), int(y_min)), (int(x_max), int(y_max)), 
                    (0, 0, 255), 2
                )
                
                # Create label with probability
                label_text = f'{action_label.upper()} ({probability:.2%})'
                
                # Draw label background
                (w, h), _ = cv2.getTextSize(
                    label_text, 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2
                )
                frame_draw = cv2.rectangle(
                    frame_draw, 
                    (int(x_min), int(y_min)-20), (int(x_min)+w, int(y_min)), 
                    (0, 0, 255), -1
                )
                
                # Draw label text with probability
                frame_draw = cv2.putText(
                    frame_draw,
                    label_text,
                    (int(x_min), int(y_min)-4),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5, (255, 255, 255),
                    thickness=2
                )
        
        # Display frame
        cv2.imshow('Multi-Person Pose Classification', frame_draw)
        
        # Break loop on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Release resources
    cap.release()
    cv2.destroyAllWindows()

# Run the webcam pose classification
if __name__ == "__main__":
    pose_classification_webcam()
# Out:
# 0: 384x640 1 person, 581.7ms
# Speed: 32.5ms preprocess, 581.7ms inference, 1537.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 230.4ms
# Speed: 4.5ms preprocess, 230.4ms inference, 64.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.7ms
# Speed: 2.0ms preprocess, 123.7ms inference, 41.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.8ms
# Speed: 1.8ms preprocess, 105.8ms inference, 40.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 1.8ms preprocess, 97.2ms inference, 40.9ms postprocess per image at shape (1, 3, 384, 640)
# 2024-11-26 15:03:23.952 python[4984:58799] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-11-26 15:03:23.952 python[4984:58799] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 1 person, 95.9ms
# Speed: 1.8ms preprocess, 95.9ms inference, 41.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.8ms
# Speed: 1.5ms preprocess, 97.8ms inference, 41.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.8ms
# Speed: 1.5ms preprocess, 97.8ms inference, 40.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 1.9ms preprocess, 100.3ms inference, 41.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.7ms
# Speed: 1.8ms preprocess, 97.7ms inference, 40.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 1.8ms preprocess, 98.2ms inference, 40.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.8ms
# Speed: 1.7ms preprocess, 96.8ms inference, 41.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 1.9ms preprocess, 100.4ms inference, 37.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 1.7ms preprocess, 101.1ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 1.9ms preprocess, 101.1ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 2.1ms preprocess, 101.5ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 1.6ms preprocess, 100.5ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 1.8ms preprocess, 97.2ms inference, 40.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.1ms preprocess, 100.3ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.0ms preprocess, 100.6ms inference, 71.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.6ms
# Speed: 2.1ms preprocess, 101.6ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.0ms preprocess, 101.3ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 1.6ms preprocess, 100.6ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 1.6ms preprocess, 100.2ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 1.9ms preprocess, 101.5ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 37.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 1.5ms preprocess, 101.7ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 2.1ms preprocess, 101.2ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.7ms
# Speed: 2.0ms preprocess, 99.7ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 1.9ms preprocess, 99.5ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 1.9ms preprocess, 100.4ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 2.1ms preprocess, 101.5ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.3ms
# Speed: 2.1ms preprocess, 107.3ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 39.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 1.9ms preprocess, 100.2ms inference, 38.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.1ms preprocess, 100.9ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 2.0ms preprocess, 99.4ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.1ms preprocess, 101.4ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.0ms preprocess, 100.1ms inference, 39.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.1ms preprocess, 100.8ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 38.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.0ms preprocess, 100.8ms inference, 39.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.3ms
# Speed: 3.0ms preprocess, 104.3ms inference, 41.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.1ms preprocess, 102.0ms inference, 37.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.0ms preprocess, 100.9ms inference, 37.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 1.9ms preprocess, 101.3ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 39.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 1.9ms preprocess, 101.3ms inference, 37.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.8ms
# Speed: 2.0ms preprocess, 102.8ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.0ms preprocess, 101.3ms inference, 39.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.6ms
# Speed: 1.9ms preprocess, 101.6ms inference, 37.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.0ms preprocess, 100.3ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.4ms
# Speed: 2.0ms preprocess, 102.4ms inference, 36.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 1.9ms preprocess, 101.2ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.1ms preprocess, 102.0ms inference, 37.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 1.9ms preprocess, 101.3ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.3ms
# Speed: 1.9ms preprocess, 99.3ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 39.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.1ms preprocess, 101.4ms inference, 37.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.0ms preprocess, 101.3ms inference, 36.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.4ms
# Speed: 1.8ms preprocess, 102.4ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.4ms
# Speed: 1.8ms preprocess, 105.4ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 36.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.2ms preprocess, 101.4ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.1ms preprocess, 101.4ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 2.1ms preprocess, 101.2ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 1.9ms preprocess, 100.2ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 2.2ms preprocess, 102.2ms inference, 36.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.1ms preprocess, 101.7ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.2ms
# Speed: 2.1ms preprocess, 104.2ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.1ms preprocess, 100.9ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.2ms preprocess, 100.5ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 1.9ms preprocess, 102.0ms inference, 36.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 37.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.0ms preprocess, 100.9ms inference, 38.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 36.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 37.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 37.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.1ms preprocess, 100.8ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.6ms
# Speed: 2.1ms preprocess, 102.6ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.0ms preprocess, 100.3ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 2.2ms preprocess, 99.1ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 1.9ms preprocess, 100.2ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 2.1ms preprocess, 100.2ms inference, 39.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.1ms preprocess, 100.5ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 36.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.2ms preprocess, 101.7ms inference, 39.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 2.1ms preprocess, 101.5ms inference, 37.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 2.2ms preprocess, 101.2ms inference, 37.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.1ms preprocess, 100.3ms inference, 37.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.1ms preprocess, 100.8ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.2ms preprocess, 101.4ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.1ms preprocess, 102.0ms inference, 36.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 1.9ms preprocess, 100.2ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 2.1ms preprocess, 100.4ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.7ms
# Speed: 2.4ms preprocess, 96.7ms inference, 41.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 2.1ms preprocess, 100.2ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.1ms preprocess, 100.3ms inference, 39.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 2.1ms preprocess, 98.4ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.2ms preprocess, 99.6ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.8ms
# Speed: 1.8ms preprocess, 102.8ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.6ms
# Speed: 2.1ms preprocess, 104.6ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.2ms
# Speed: 1.9ms preprocess, 99.2ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 2.1ms preprocess, 99.8ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.0ms
# Speed: 2.1ms preprocess, 101.0ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.1ms preprocess, 100.9ms inference, 39.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 1.9ms preprocess, 100.5ms inference, 39.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 37.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 1.8ms preprocess, 99.8ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.7ms
# Speed: 2.0ms preprocess, 95.7ms inference, 40.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 2.0ms preprocess, 98.2ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.2ms
# Speed: 2.2ms preprocess, 99.2ms inference, 36.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 1.9ms preprocess, 100.1ms inference, 37.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 36.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.0ms preprocess, 100.8ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 37.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 2.2ms preprocess, 99.5ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 2.2ms preprocess, 99.5ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 1.9ms preprocess, 101.3ms inference, 39.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.0ms
# Speed: 2.1ms preprocess, 99.0ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 39.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 36.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.3ms
# Speed: 2.0ms preprocess, 98.3ms inference, 39.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.1ms preprocess, 100.5ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.2ms preprocess, 100.1ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 2.2ms preprocess, 99.8ms inference, 39.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.2ms preprocess, 99.9ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 1.9ms preprocess, 101.2ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.1ms preprocess, 100.5ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.4ms
# Speed: 2.0ms preprocess, 103.4ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 2.1ms preprocess, 99.5ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.6ms
# Speed: 1.9ms preprocess, 101.6ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 70.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.0ms preprocess, 100.1ms inference, 68.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 2.1ms preprocess, 100.2ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 2.1ms preprocess, 99.1ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.9ms
# Speed: 1.8ms preprocess, 98.9ms inference, 37.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 2.1ms preprocess, 99.1ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.3ms
# Speed: 2.1ms preprocess, 99.3ms inference, 38.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.3ms preprocess, 100.9ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.7ms
# Speed: 2.2ms preprocess, 96.7ms inference, 36.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.7ms
# Speed: 1.9ms preprocess, 98.7ms inference, 37.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.8ms
# Speed: 1.9ms preprocess, 98.8ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 2.1ms preprocess, 99.8ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 1.9ms preprocess, 100.1ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.2ms preprocess, 100.8ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.0ms preprocess, 100.1ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 38.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.1ms preprocess, 99.9ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.3ms preprocess, 99.6ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 1.8ms preprocess, 99.1ms inference, 39.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 97.3ms
# Speed: 1.8ms preprocess, 97.3ms inference, 358.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.9ms
# Speed: 2.2ms preprocess, 109.9ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 2.2ms preprocess, 101.2ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.6ms
# Speed: 2.1ms preprocess, 102.6ms inference, 40.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.1ms preprocess, 99.6ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.1ms preprocess, 101.4ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 69.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 1.9ms preprocess, 100.0ms inference, 39.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.3ms preprocess, 101.4ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.1ms preprocess, 99.6ms inference, 39.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 2.1ms preprocess, 99.5ms inference, 39.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.2ms preprocess, 100.8ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 39.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.7ms
# Speed: 2.1ms preprocess, 100.7ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.1ms preprocess, 100.1ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.0ms preprocess, 100.3ms inference, 39.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 1.9ms preprocess, 99.5ms inference, 38.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 2.2ms preprocess, 101.1ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.2ms preprocess, 99.9ms inference, 38.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 2.1ms preprocess, 100.0ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 37.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 2.0ms preprocess, 99.4ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.6ms
# Speed: 2.1ms preprocess, 102.6ms inference, 38.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.9ms
# Speed: 2.2ms preprocess, 98.9ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.9ms
# Speed: 2.6ms preprocess, 111.9ms inference, 42.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 1.8ms preprocess, 101.1ms inference, 38.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 2.1ms preprocess, 100.2ms inference, 38.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.3ms preprocess, 99.9ms inference, 40.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.0ms
# Speed: 1.9ms preprocess, 104.0ms inference, 39.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.8ms
# Speed: 1.8ms preprocess, 102.8ms inference, 40.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.9ms
# Speed: 2.3ms preprocess, 118.9ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 2.1ms preprocess, 101.5ms inference, 40.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.7ms
# Speed: 2.1ms preprocess, 111.7ms inference, 38.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.5ms
# Speed: 2.1ms preprocess, 103.5ms inference, 36.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.0ms
# Speed: 2.1ms preprocess, 103.0ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.8ms
# Speed: 1.8ms preprocess, 101.8ms inference, 37.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.5ms
# Speed: 2.1ms preprocess, 98.5ms inference, 39.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.1ms preprocess, 100.3ms inference, 38.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.3ms
# Speed: 5.0ms preprocess, 106.3ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 36.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.9ms
# Speed: 2.0ms preprocess, 102.9ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.7ms
# Speed: 1.9ms preprocess, 109.7ms inference, 34.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 36.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.1ms
# Speed: 2.1ms preprocess, 109.1ms inference, 34.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 40.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.2ms preprocess, 100.8ms inference, 35.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.5ms
# Speed: 2.0ms preprocess, 106.5ms inference, 35.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.1ms preprocess, 99.6ms inference, 35.3ms postprocess per image at shape (1, 3, 384, 640)
